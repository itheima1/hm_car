# %%
# 定义
d = {'name': 'itcast', 'age': 16}
print(d)
print(type(d))
# Out:
# {'name': 'itcast', 'age': 16}
# <class 'dict'>

# %%
# 长度
d = {'name': 'itcast', 'age': 16, 'gender': True}
print(len(d))
# Out:
# 3

# %%
# 可访问，通过key
d = {'name': 'itcast', 'age': 16, 'gender': True}
print(d['name'])
print(d['age'])
print(d['gender'])
# Out:
# itcast
# 16
# True

# %%
# 添加
d = {'name': 'itcast', 'age': 16, 'gender': True}
d['address'] = 'sz'
print(d)
# Out:
# {'name': 'itcast', 'age': 16, 'gender': True, 'address': 'sz'}

# %%
# 修改
d = {'name': 'itcast', 'age': 16, 'gender': True}
d['name'] = 'itheima'
print(d)
# Out:
# {'name': 'itheima', 'age': 16, 'gender': True}

# %%
# 删除 del
d = {'name': 'itcast', 'age': 16, 'gender': True}
del d['name']
print(d)
# Out:
# {'age': 16, 'gender': True}

# %%
# 删除 pop
d = {'name': 'itcast', 'age': 16, 'gender': True}
d.pop('name')
print(d)
# Out:
# {'age': 16, 'gender': True}

# %%
# 清空
d = {'name': 'itcast', 'age': 16, 'gender': True}
d.clear()
print(d)
# Out:
# {}

# %%
# 复杂类型数据
stu = {'name': 'itcast', 'age': 16, 'gender': True}
stus = {'name': {'age': 16, 'gender': True}}
