# %% [markdown]
# 机器学习开发任务包含：
#
# * 数据收集
# * 数据校验
# * 特征提取
# * 数据标注
# * 资源管理
# * 系统架构设计
# * 机器学习模型和算法
# * 分析工具
# * 算法部署
# * 运维

# %% [markdown]
# ## VGG16/19

# %%
# https://arxiv.org/pdf/1409.1556.pdf
# 构建一下vgg16的网络。

# %%
import tensorflow as tf
from tensorflow.keras.models import *
from tensorflow.keras.layers import *

# %%
# 构建cnn的网络模型 实现vgg16
model = Sequential()
model.add(Conv2D(filters =64,kernel_size=(3,3),activation='relu',input_shape=(224,224,3)))
model.add(Conv2D(filters =64,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Conv2D(filters =128,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =128,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Conv2D(filters =256,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =256,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =256,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))


model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(Conv2D(filters =512,kernel_size=(3,3),activation='relu'))
model.add(MaxPool2D(pool_size=(2,2),strides=(2,2)))

model.add(Flatten())
model.add(Dense(4096,activation='relu'))
model.add(Dense(4096,activation='relu'))
model.add(Dense(1000,activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_6 (Conv2D)            (None, 222, 222, 64)      1792
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 220, 220, 64)      36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 110, 110, 64)      0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 108, 108, 128)     73856
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 106, 106, 128)     147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 53, 53, 128)       0
# _________________________________________________________________
# conv2d_10 (Conv2D)           (None, 51, 51, 256)       295168
# ...

# %% [markdown]
# | 模型名称          | 大小  | 精度  | 参数量      | 深度 |
# | ----------------- | ----- | ----- | ----------- | ---- |
# | Xception          | 88MB  | 0.945 | 22,910,480  | 126  |
# | VGG16             | 528MB | 0.901 | 138,357,544 | 23   |
# | VGG19             | 549MB | 0.900 | 143,667,240 | 26   |
# | ResNet50          | 98MB  | 0.921 | 25,636,712  | 50   |
# | ResNet101         | 171MB | 0.928 | 44,707,176  | 101  |
# | ResNet152         | 232MB | 0.931 | 60,419,944  | 152  |
# | InceptionV3       | 92MB  | 0.937 | 23,851,784  | 159  |
# | InceptionResNetV2 | 215MB | 0.953 | 55,873,736  | 572  |
# | MobileNet         | 16MB  | 0.895 | 4,253,864   | 88   |
# | MobileNetV2       | 14MB  | 0.901 | 3,538,984   | 88   |
# | DenseNet121       | 33MB  | 0.923 | 8,062,504   | 121  |
# | DenseNet169       | 57MB  | 0.932 | 14,307,880  | 169  |
# | DenseNet201       | 80MB  | 0.936 | 20,242,984  | 201  |

# %% [markdown]
# # 预训练好的模型

# %%
tf.keras.applications.xception.Xception(include_top=True, weights='imagenet', 
                                        input_tensor=None, 
                                        input_shape=None, pooling=None, classes=1000)
# Out:
# ...
# 91889664/91884032 [==============================] - 15s 0us/step

# %%
tf.keras.applications.resnet50.ResNet50(include_top=True, weights='imagenet', 
                                        input_tensor=None, input_shape=None, pooling=None, classes=1000)
# Out:
# ...
# 102973440/102967424 [==============================] - 18s 0us/step

# %% [markdown]
# ## inceptionV3 google

# %%
import numpy as np
from tensorflow.keras.applications.inception_v3 import *
model = InceptionV3()
model.summary()
# Out:
# Model: "inception_v3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_5 (InputLayer)            [(None, 299, 299, 3) 0
# __________________________________________________________________________________________________
# conv2d_211 (Conv2D)             (None, 149, 149, 32) 864         input_5[0][0]
# __________________________________________________________________________________________________
# batch_normalization_192 (BatchN (None, 149, 149, 32) 96          conv2d_211[0][0]
# __________________________________________________________________________________________________
# activation_188 (Activation)     (None, 149, 149, 32) 0           batch_normalization_192[0][0]
# __________________________________________________________________________________________________
# ...

# %%
import cv2
image = cv2.imread('zz.jpeg')
x = cv2.resize(image,(299,299))
## 模型预测

decode_predictions(model.predict(np.array([x])/255.0))
# Out:
# [[('n03201208', 'dining_table', 0.61730546),
#   ('n03179701', 'desk', 0.20154633),
#   ('n03903868', 'pedestal', 0.0998681),
#   ('n03337140', 'file', 0.008167368),
#   ('n04380533', 'table_lamp', 0.0033764488)]]

# %% [markdown]
# ## mobilenet

# %%
from tensorflow.keras.applications.mobilenet_v2 import MobileNetV2

# %%
## 载入mobilenet的imagenet数据集预训练的模型
model = MobileNetV2(weights='imagenet')
model.summary()
# Out:
# Model: "mobilenetv2_1.00_224"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_7 (InputLayer)            [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# Conv1_pad (ZeroPadding2D)       (None, 225, 225, 3)  0           input_7[0][0]
# __________________________________________________________________________________________________
# Conv1 (Conv2D)                  (None, 112, 112, 32) 864         Conv1_pad[0][0]
# __________________________________________________________________________________________________
# bn_Conv1 (BatchNormalization)   (None, 112, 112, 32) 128         Conv1[0][0]
# __________________________________________________________________________________________________
# Conv1_relu (ReLU)               (None, 112, 112, 32) 0           bn_Conv1[0][0]
# ...

# %%
import cv2
image = cv2.imread('ddd.jpg')
x = cv2.resize(image,(224,224))
## 模型预测
decode_predictions(model.predict(np.array([x])/255.0))
# Out:
# [[('n02480855', 'gorilla', 0.6607095),
#   ('n02480495', 'orangutan', 0.17576869),
#   ('n02481823', 'chimpanzee', 0.0076405797),
#   ('n02484975', 'guenon', 0.0044357684),
#   ('n02486410', 'baboon', 0.0038167413)]]
